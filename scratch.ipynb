# %%
import sys 
sys.path.append('pyfiles/')
import classes_loop as cl
import parametrics as par
from input import read_obj
from plot import plot_complex
from complex import augment_with_radialdist, complex

# so we don't have to reboot kernel every time we modify classes.py
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from math import *
cplx = read_obj("input/blob.obj")
cplx.key_point = [0.00001, 0.00001]
augment_with_radialdist(cplx)
cplx.sort_by_dist([v.radialdist for v in cplx.vertlist])
plt = plot_complex(cplx)
