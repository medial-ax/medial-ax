# %%
import sys 
sys.path.append('pyfiles/')
import parametrics as par
import input as inp 
import plot as pl
import complex as cp

# so we don't have to reboot kernel every time we modify classes.py
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from math import *
cplx = inp.read_obj("input/blob.obj")
cplx.key_point = [0.0, 0]
cp.augment_with_radialdist(cplx)
cplx.sort_by_dist([v.radialdist for v in cplx.vertlist])
plt = pl.plot_complex(cplx)

# %%
cplx.vertlist
# Out:
# [simplex ind 0, dim 0, bd [-1], col val 146,
#  simplex ind 1, dim 0, bd [-1], col val 139,
#  simplex ind 2, dim 0, bd [-1], col val 136,
#  simplex ind 3, dim 0, bd [-1], col val 137,
#  simplex ind 4, dim 0, bd [-1], col val 141,
#  simplex ind 5, dim 0, bd [-1], col val 192,
#  simplex ind 6, dim 0, bd [-1], col val 255,
#  simplex ind 7, dim 0, bd [-1], col val 279,
#  simplex ind 8, dim 0, bd [-1], col val 293,
#  simplex ind 9, dim 0, bd [-1], col val 303,
#  simplex ind 10, dim 0, bd [-1], col val 297,
#  simplex ind 11, dim 0, bd [-1], col val 277,
#  simplex ind 12, dim 0, bd [-1], col val 214,
#  simplex ind 13, dim 0, bd [-1], col val 134,
#  simplex ind 14, dim 0, bd [-1], col val 122,
#  simplex ind 15, dim 0, bd [-1], col val 108,
#  simplex ind 16, dim 0, bd [-1], col val 98,
#  simplex ind 17, dim 0, bd [-1], col val 82,
#  simplex ind 18, dim 0, bd [-1], col val 66,
#  simplex ind 19, dim 0, bd [-1], col val 56,
#  simplex ind 20, dim 0, bd [-1], col val 50,
# ...
